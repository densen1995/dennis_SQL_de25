# %%
import duckdb
from pathlib import Path

# %%
# handle paths
duckdb_path = "data/sakila.duckdb"
#Path(duckdb_path).unlink(missing_ok=True)

# connect to duckdb file with context manager
with duckdb.connect(duckdb_path) as conn, open("sql/load_sakila.sql") as ingest_scripts:
    conn.sql(ingest_scripts.read())
    # create pandas dataframes from the created duckdb connection
    description = conn.sql("DESC;").df()
    film = conn.sql("FROM film;").df()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[4], line 6
#       2 duckdb_path = "data/sakila.duckdb"
#       3 #Path(duckdb_path).unlink(missing_ok=True)
#       4
#       5 # connect to duckdb file with context manager
# ----> 6 with duckdb.connect(duckdb_path) as conn, open("sql/load_sakila.sql") as ingest_scripts:
#       7     conn.sql(ingest_scripts.read())
#       8     # create pandas dataframes from the created duckdb connection
#
# Cell In[4], line 7
#       3 #Path(duckdb_path).unlink(missing_ok=True)
#       4
#       5 # connect to duckdb file with context manager
#       6 with duckdb.connect(duckdb_path) as conn, open("sql/load_sakila.sql") as ingest_scripts:
# ----> 7     conn.sql(ingest_scripts.read())
#       8     # create pandas dataframes from the created duckdb connection
#       9     description = conn.sql("DESC;").df()
#
# Error: Unable to open database "data/sqlite-sakila.duckdb": unable to open database file
